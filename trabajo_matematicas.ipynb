# %%
import pandas as pd
matriculas = pd.read_excel(r'C:/Users/ivory/OneDrive/Escritorio/trabajo_Matematicas/16_MATRICULAS_ED_SUPERIOR_MAGALLANES_2021.xlsx')
matriculas
# Out:
#            ID     GENERO  EDAD RANGO EDAD  AÑO INGRESO SEMESTRE INGRESO  \
# 0         261  Masculino    19   15 a 19          2021  Primer semestre
# 1         341   Femenino    26   25 a 29          2015  Primer semestre
# 2         521  Masculino    19   15 a 19          2020  Primer semestre
# 3         551   Femenino    37   35 a 39          2021  Primer semestre
# 4         898   Femenino    19   15 a 19          2021  Primer semestre
# ...       ...        ...   ...        ...          ...              ...
# 5791  1047164   Femenino    18   15 a 19          2021  Primer semestre
# 5792  1047823   Femenino    24   20 a 24          2016  Primer semestre
# 5793  1048083  Masculino    18   15 a 19          2021  Primer semestre
# 5794  1048090   Femenino    21   20 a 24          2018  Primer semestre
# 5795  1048116   Femenino    26   25 a 29          2019  Primer semestre
#
#                TIPO DE INSTITUCION                    NOMBRE DE INSTITUCION  \
# ...
